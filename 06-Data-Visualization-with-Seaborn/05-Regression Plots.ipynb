# %% [markdown]
# # Regression Plots
#
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the **`lmplot()`** function for now.
#
# **`lmplot`** allows you to display <font color=blue>linear models</font>, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore how this works:

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## lmplot()
#
# Pass x-axis variable (independent variable) and y-axis variable (dependent variable). For example below, How the total bill (x) affects the tip amount (y)?

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# We can also add a categorical variable using `hue=cat_variable`.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %% [markdown]
# **INTERPRETATION**: It looks like there is a positive relationship between the total amount and tip amount. And there is no significant difference between male and female categories.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %% [markdown]
# ### Working with Markers
#
# lmplot kwargs get passed through to **regplot** which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So you want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, you probably won't remember this off the top of your head, but instead reference the documentation.

# %%
# http://matplotlib.org/api/markers_api.html
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})

# %% [markdown]
# ## Using a Grid
#
# We can add more variable separation through **columns and rows** with the use of a grid. Just indicate this with the col or row arguments:

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %% [markdown]
# As you can see, instead of having one plot with both genders, now we have two different plots side by side denoting each element of sex categorical variable.

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %% [markdown]
# Now we will pass `col="day"` to our `.lmplot()` function. As you can see there are 4 columns, since we have 4 different days in our `day` variable.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm')

# %% [markdown]
# ## Aspect and Size
#
# Seaborn figures can have their size and aspect ratio adjusted with the **height (it was size before)** and **aspect** parameters:

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,height=8)

# %% [markdown]
# You're probably wondering how to change the font size or control the aesthetics even more, check out the Style and Color Lecture and Notebook for more info on that!
#
# # Great Job!
